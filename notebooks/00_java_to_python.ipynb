# %% [markdown]
# # Modul 00 – Von Java zu Python
#
# Willkommen im Brückenkurs von **Java** zu **Python** 🐍
#
# In diesem Notebook siehst du die wichtigsten Unterschiede zwischen Java und Python in kompakten Beispielen.
# Ziel ist, dass du dich schnell zurechtfindest, wenn du schon etwas Java-Erfahrung hast.
#
# ---
# ## Inhalt
#
# 1. Kommentare & Ausgaben
# 2. Variablen & Datentypen
# 3. If-Abfragen
# 4. Schleifen (`for`, `while`)
# 5. Listen vs. Arrays / ArrayList
# 6. Funktionen vs. Methoden
# 7. Klassen – Java-Klasse vs. Python-Klasse
# 8. Kleine Übungsaufgaben
#
# Hinweis: Du musst **kein Java können**, um diesem Notebook zu folgen –
# die Java-Seite ist als Vergleich gedacht. Wenn du Java nicht kennst, orientiere dich einfach an den Python-Beispielen.

# %% [markdown]
# ## 1. Kommentare & Ausgaben
#
# **Java:**
# ```java
# // Einzeiliger Kommentar
# System.out.println("Hallo Welt");
# ```
#
# **Python:**
# ```python
# # Einzeiliger Kommentar
# print("Hallo Welt")
# ```
#
# - Statt `//` benutzt Python `#` für Kommentare.
# - Statt `System.out.println(...)` gibt es einfach `print(...)`.

# %%
# Probiere aus:
# Ändere den Text und führe die Zelle aus.

print("Hallo Medieninformatik!")

# %% [markdown]
# ## 2. Variablen & Datentypen
#
# **Java:**
# ```java
# int x = 5;
# double y = 3.14;
# String name = "Alex";
# ```
#
# Du musst den Datentyp vorher angeben.
#
# **Python:**
# ```python
# x = 5
# y = 3.14
# name = "Alex"
# ```
#
# - Keine Typdeklaration nötig, Python erkennt den Typ automatisch.
# - Strings werden mit einfachen `'` oder doppelten `"` Anführungszeichen geschrieben.

# %%
# Beispiel: Variablen in Python

x = 5
y = 3.14
name = "Alex"

print("x:", x)
print("y:", y)
print("name:", name)
print("Typ von x:", type(x))
print("Typ von y:", type(y))
print("Typ von name:", type(name))

# %% [markdown]
# ### Mini-Übung 1
#
# Lege drei Variablen an:
# - `a` mit einer ganzen Zahl
# - `b` mit einer Kommazahl
# - `text` mit einem kurzen String
#
# Gib alle drei mit `print(...)` aus.

# %%
# TODO: Lösung für Mini-Übung 1
# a = ...
# b = ...
# text = ...

# print(...)

# Du kannst z.B. am Ende einen kleinen Test machen:
a = 10
b = 2.5
text = "Hallo"

print(a, b, text)

# %% [markdown]
# ## 3. If-Abfragen
#
# **Java:**
# ```java
# if (x > 10) {
#     System.out.println("x ist größer als 10");
# } else {
#     System.out.println("x ist nicht größer als 10");
# }
# ```
#
# **Python:**
# ```python
# if x > 10:
#     print("x ist größer als 10")
# else:
#     print("x ist nicht größer als 10")
# ```
#
# Unterschiede:
# - Keine `{}`-Klammern – der Block wird durch **Einrückung** (Indentation) definiert.
# - Doppelpunkt `:` am Ende der `if`- und `else`-Zeile.
# - Kein `;` am Zeilenende.

# %%
x = 7

if x > 10:
    print("x ist größer als 10")
else:
    print("x ist nicht größer als 10")

# %% [markdown]
# ### Mini-Übung 2
#
# Schreibe eine `if`-Abfrage, die prüft, ob eine Variable `zahl` **gerade** ist.
#
# Tipp: Eine Zahl ist gerade, wenn `zahl % 2 == 0`.

# %%
# TODO: Lösung für Mini-Übung 2
zahl = 7

if zahl % 2 == 0:
    print("gerade")
else:
    print("ungerade")

# %% [markdown]
# ## 4. Schleifen
#
# ### for-Schleife
#
# **Java:**
# ```java
# for (int i = 0; i < 5; i++) {
#     System.out.println(i);
# }
# ```
#
# **Python:**
# ```python
# for i in range(5):
#     print(i)
# ```
#
# - `range(5)` erzeugt die Zahlen `0, 1, 2, 3, 4`.
# - Kein Inkrement `i++` nötig, das übernimmt `range`.

# %%
for i in range(5):
    print("i =", i)

# %% [markdown]
# ### while-Schleife
#
# **Java:**
# ```java
# int i = 0;
# while (i < 3) {
#     System.out.println(i);
#     i++;
# }
# ```
#
# **Python:**
# ```python
# i = 0
# while i < 3:
#     print(i)
#     i += 1
# ```

# %%
i = 0
while i < 3:
    print("i =", i)
    i += 1

# %% [markdown]
# ## 5. Listen vs. Arrays / ArrayList
#
# **Java (Array):**
# ```java
# int[] zahlen = {1, 2, 3};
# ```
#
# **Java (ArrayList):**
# ```java
# ArrayList<Integer> liste = new ArrayList<>();
# liste.add(1);
# liste.add(2);
# ```
#
# **Python (Liste):**
# ```python
# zahlen = [1, 2, 3]
# zahlen.append(4)
# ```
#
# - Die Standard-Datenstruktur für geordnete Sammlungen in Python ist die **Liste** (`list`).
# - Listen können verschiedene Typen gleichzeitig enthalten (z. B. Zahlen und Strings).

# %%
zahlen = [1, 2, 3]
zahlen.append(4)
print(zahlen)
print("Erstes Element:", zahlen[0])
print("Länge der Liste:", len(zahlen))

# %% [markdown]
# ### Mini-Übung 3
#
# Erzeuge eine Liste `namen` mit drei Namen deiner Wahl.
# Gib alle Namen mit einer `for`-Schleife aus.

# %%
# TODO: Lösung für Mini-Übung 3
namen = ["Alex", "Sam", "Riley"]

for n in namen:
    print(n)

# %% [markdown]
# ## 6. Funktionen vs. Methoden
#
# **Java (Methode in einer Klasse):**
# ```java
# public static int add(int a, int b) {
#     return a + b;
# }
# ```
#
# **Python (Funktion):**
# ```python
# def add(a, b):
#     return a + b
# ```
#
# - Kein `public`, `static` oder Typangabe nötig.
# - Funktionen können überall (auch außerhalb von Klassen) definiert werden.

# %%
def add(a, b):
    return a + b

print("2 + 3 =", add(2, 3))

# %% [markdown]
# ### Mini-Übung 4
#
# Schreibe eine Funktion `square(x)`, die das Quadrat von `x` zurückgibt.
#
# Beispiel: `square(3)` → `9`.

# %%
# TODO: Lösung für Mini-Übung 4
def square(x):
    return x * x

# Test
print(square(3))  # sollte 9 ausgeben

# %% [markdown]
# ## 7. Klassen – Java-Klasse vs. Python-Klasse
#
# **Java:**
# ```java
# public class Person {
#     private String name;
#     private int age;
#
#     public Person(String name, int age) {
#         this.name = name;
#         this.age = age;
#     }
#
#     public String greet() {
#         return "Hallo, ich heiße " + name;
#     }
# }
# ```
#
# **Python:**
# ```python
# class Person:
#     def __init__(self, name, age):
#         self.name = name
#         self.age = age
#
#     def greet(self):
#         return f"Hallo, ich heiße {self.name}"
# ```
#
# - Der Konstruktor heißt in Python immer `__init__`.
# - `self` entspricht grob `this` in Java.
# - Attribute werden einfach über `self.name` zugewiesen.

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        return f"Hallo, ich heiße {self.name} und bin {self.age} Jahre alt."

p = Person("Alex", 21)
print(p.greet())

# %% [markdown]
# ## 8. Kleine Abschluss-Übung
#
# Schreibe eine kleine Klasse `Song` mit:
# - Attributen: `title` (String), `length_seconds` (int)
# - einer Methode `describe()`, die z. B. zurückgibt:
#
#   `"Song: <Titel>, Dauer: <Min:Sek>"`
#
# Hinweis: Du kannst Minuten und Sekunden etwa so berechnen:
#
# ```python
# minutes = length_seconds // 60
# seconds = length_seconds % 60
# ```

# %%
# TODO: Klasse Song implementieren

class Song:
    def __init__(self, title, length_seconds):
        self.title = title
        self.length_seconds = length_seconds

    def describe(self):
        minutes = self.length_seconds // 60
        seconds = self.length_seconds % 60
        return f"Song: {self.title}, Dauer: {minutes}:{seconds:02d} Minuten"

# Test
s = Song("Test Song", 197)
print(s.describe())

# %% [markdown]
# ---
# ## Zusammenfassung
#
# - Python ist **weniger formal** als Java: keine Typdeklarationen, keine Semikolons, keine `{}`-Blöcke.
# - Blöcke werden durch **Einrückung** definiert – achte auf Leerzeichen/Tab.
# - Listen sind sehr flexibel und werden statt Arrays/ArrayList verwendet.
# - Funktionen und Klassen sind einfacher zu schreiben, haben aber ähnliche Konzepte.
#
# Wenn du dich mit diesem Notebook wohlfühlst, bist du bereit für:
# - `01_basics.ipynb` (Grundlagen in Python vertiefen)
# - und die zugehörigen Übungen in deinem Level (A/B/C).
#
# Speichere das Notebook ruhig ab – dann kannst du später sehen, wie du gestartet bist 🙂
