# %% [markdown]
# # Modul 04 – Datenstrukturen in Python
#
# In diesem Modul lernst du die wichtigsten **Datenstrukturen** in Python kennen:
#
# 1. Listen (`list`)
# 2. Tupel (`tuple`)
# 3. Dictionaries (`dict`)
# 4. Sets (`set`)
# 5. Kombinationen dieser Strukturen
#
# Ziel: Du kannst Daten sinnvoll strukturieren – z. B. Playlists, Nutzerprofile oder Einstellungen – und bequem darauf zugreifen.

# %% [markdown]
# ## 1. Listen (`list`)
#
# Listen sind **geordnete**, veränderbare Sammlungen von Elementen.
#
# ```python
# numbers = [1, 2, 3]
# names = ["Alex", "Sam", "Riley"]
# mixed = [1, "Hallo", 3.14]
# ```
#
# Du kannst über den **Index** zugreifen (beginnend bei 0):
#
# ```python
# names[0]  # "Alex"
# ```

# %%
numbers = [1, 2, 3, 4]
names = ["Alex", "Sam", "Riley"]

print("numbers:", numbers)
print("names:", names)
print("Erstes Element von names:", names[0])
print("Länge von names:", len(names))

# %% [markdown]
# ### Wichtige Listen-Operationen
#
# - `append(x)` – ans Ende anhängen
# - `insert(i, x)` – an Position `i` einfügen
# - `remove(x)` – erstes Vorkommen von `x` entfernen
# - `pop(i)` – Element an Position `i` entfernen und zurückgeben
# - `in` – prüfen, ob ein Element enthalten ist

# %%
playlist = ["Song A", "Song B", "Song C"]
print("Start:", playlist)

playlist.append("Song D")
print("Nach append:", playlist)

playlist.insert(1, "Intro")
print("Nach insert an Position 1:", playlist)

playlist.remove("Song B")
print("Nach remove('Song B'):", playlist)

last = playlist.pop()
print("Nach pop():", playlist, "(entfernt:", last, ")")

print("Enthält 'Song A'?:", "Song A" in playlist)

# %% [markdown]
# ### Mini-Übung 1 – Eigene Playlist
#
# Erzeuge eine Liste `my_playlist` mit mindestens drei Songtiteln.
#
# - Hänge einen weiteren Song an.
# - Entferne einen Song.
# - Gib am Ende die finale Playlist aus.

# %%
# TODO: Mini-Übung 1 – Eigene Playlist
my_playlist = ["Song 1", "Song 2", "Song 3"]
my_playlist.append("Song 4")
my_playlist.remove("Song 2")
print("Meine Playlist:", my_playlist)

# %% [markdown]
# ## 2. Tupel (`tuple`)
#
# Tupel sind **geordnete, aber unveränderliche** Sammlungen.
#
# ```python
# position = (100, 200)
# color = (255, 128, 0)
# ```
#
# Du kannst zugreifen wie bei Listen, aber nicht verändern:
#
# ```python
# position[0]  # 100
# ```

# %%
screen_size = (1920, 1080)
print("Breite:", screen_size[0])
print("Höhe:", screen_size[1])

# screen_size[0] = 1280  # würde einen Fehler auslösen (unveränderlich)

# %% [markdown]
# ### Tupel als Rückgabewerte
#
# Tupel eignen sich gut, um mehrere Werte aus einer Funktion zurückzugeben (z. B. Minuten und Sekunden). Du hast das schon in Modul 03 gesehen.
#
# Beispiel:
#
# ```python
# def get_resolution():
#     return (1920, 1080)
#
# width, height = get_resolution()
# ```

# %% [markdown]
# ## 3. Dictionaries (`dict`)
#
# Dictionaries speichern **Schlüssel-Wert-Paare**.
#
# ```python
# user = {
#     "name": "Alex",
#     "age": 21,
#     "study_program": "Medieninformatik"
# }
# ```
#
# Zugriff über den **Schlüssel**:
#
# ```python
# user["name"]  # "Alex"
# ```

# %%
user = {
    "name": "Alex",
    "age": 21,
    "study_program": "Medieninformatik"
}

print("Name:", user["name"])
print("Alter:", user["age"])
print("Studiengang:", user["study_program"])

# %% [markdown]
# ### Einträge hinzufügen, ändern, löschen
#
# - Neuen Schlüssel hinzufügen:
#   ```python
#   user["favorite_medium"] = "Film"
#   ```
# - Wert ändern:
#   ```python
#   user["age"] = 22
#   ```
# - Eintrag löschen:
#   ```python
#   del user["age"]
#   ```
# - Prüfen, ob ein Schlüssel existiert:
#   ```python
#   "name" in user
#   ```

# %%
print("Start:", user)

user["favorite_medium"] = "Film"
print("Nach hinzufügen von favorite_medium:", user)

user["age"] = 22
print("Nach Änderung von age:", user)

print("Hat Schlüssel 'name'?:", "name" in user)

del user["study_program"]
print("Nach del study_program:", user)

# %% [markdown]
# ### Über Dictionaries iterieren
#
# Du kannst über Schlüssel, Werte oder beides iterieren:
#
# ```python
# for key in user.keys():
#     ...
#
# for value in user.values():
#     ...
#
# for key, value in user.items():
#     ...
# ```

# %%
print("Schlüssel:")
for key in user.keys():
    print(" -", key)

print("Werte:")
for value in user.values():
    print(" -", value)

print("Schlüssel und Werte:")
for key, value in user.items():
    print(f" - {key}: {value}")

# %% [markdown]
# ### Mini-Übung 2 – Medienprofil
#
# Erzeuge ein Dictionary `profile` mit z. B. folgenden Schlüsseln:
#
# - `"name"`
# - `"likes_music"` (bool)
# - `"hours_music_per_week"` (float)
# - `"favorite_genre"`
#
# Gib alle Schlüssel und Werte schön formatiert aus.

# %%
# TODO: Mini-Übung 2 – Medienprofil
profile = {
    "name": "Alex",
    "likes_music": True,
    "hours_music_per_week": 6.5,
    "favorite_genre": "LoFi"
}

for key, value in profile.items():
    print(f"{key}: {value}")

# %% [markdown]
# ## 4. Sets (`set`)
#
# Sets sind **ungeordnete Mengen ohne Duplikate**.
#
# ```python
# tags = {"music", "film", "game"}
# ```
#
# Du kannst Elemente hinzufügen oder entfernen, aber es gibt keine festen Positionen (keine Indizes).

# %%
tags = {"music", "film", "game"}
print("Start:", tags)

tags.add("podcast")
print("Nach add('podcast'):", tags)

tags.add("music")  # Duplikat – Set bleibt gleich
print("Nach add('music') (Duplikat):", tags)

tags.remove("film")
print("Nach remove('film'):", tags)

print("Enthält 'game'?:", "game" in tags)

# %% [markdown]
# ### Mengenoperationen
#
# Sets unterstützen typische Mengenoperationen:
#
# - Vereinigung (`|`)
# - Schnittmenge (`&`)
# - Differenz (`-`)
#
# Beispiel:
#
# ```python
# user1_tags = {"music", "film"}
# user2_tags = {"music", "game"}
#
# gemeinsam = user1_tags & user2_tags       # Schnittmenge
# alle = user1_tags | user2_tags            # Vereinigung
# nur_user1 = user1_tags - user2_tags       # Differenz
# ```

# %%
user1_tags = {"music", "film"}
user2_tags = {"music", "game"}

gemeinsam = user1_tags & user2_tags
alle = user1_tags | user2_tags
nur_user1 = user1_tags - user2_tags

print("User1-Tags:", user1_tags)
print("User2-Tags:", user2_tags)
print("Gemeinsam:", gemeinsam)
print("Alle:", alle)
print("Nur User1:", nur_user1)

# %% [markdown]
# ### Mini-Übung 3 – Interessensüberschneidung
#
# Definiere zwei Sets `person_a` und `person_b` mit Medieninteressen (z. B. `{"film", "musik", "podcast"}` etc.).
#
#     Berechne und gib aus:
#
# - Gemeinsamkeiten
# - Alle Interessen
# - Interessen, die nur `person_a` hat.

# %%
# TODO: Mini-Übung 3 – Interessensüberschneidung
person_a = {"film", "musik", "podcast"}
person_b = {"musik", "game"}

print("Gemeinsamkeiten:", person_a & person_b)
print("Alle Interessen:", person_a | person_b)
print("Nur Person A:", person_a - person_b)

# %% [markdown]
# ## 5. Strukturen kombinieren
#
# In echten Anwendungen kombinierst du diese Strukturen oft.
#
# Beispiele:
#
# - Liste von Dictionaries
# - Dictionary, das auf Listen zeigt
# - Liste von Tupeln
#
# ### Beispiel: Liste von Nutzerprofilen
#
# ```python
# users = [
#     {"name": "Alex", "likes_music": True},
#     {"name": "Sam", "likes_music": False},
# ]
# ```

# %%
users = [
    {"name": "Alex", "likes_music": True, "hours_music": 6.0},
    {"name": "Sam", "likes_music": False, "hours_music": 0.5},
    {"name": "Riley", "likes_music": True, "hours_music": 2.5},
]

for user in users:
    print(f"{user['name']} – Musikfan: {user['likes_music']} – Stunden/Woche: {user['hours_music']}")

# %% [markdown]
# ### Mini-Übung 4 – Kleine User-Liste
#
# Erzeuge eine Liste `accounts` mit mindestens drei Dictionaries, die je ein einfaches Profil enthalten:
#
# - `"name"`
# - `"favorite_medium"`
# - `"hours_per_week"`
#
# Gib für jeden Account einen Text aus, z. B.:
#
# `"Alex verbringt 5.0 Stunden pro Woche mit Film."`

# %%
# TODO: Mini-Übung 4 – Kleine User-Liste
accounts = [
    {"name": "Alex", "favorite_medium": "Film", "hours_per_week": 5.0},
    {"name": "Sam", "favorite_medium": "Game", "hours_per_week": 8.0},
    {"name": "Riley", "favorite_medium": "Musik", "hours_per_week": 6.5},
]

for acc in accounts:
    print(f"{acc['name']} verbringt {acc['hours_per_week']} Stunden pro Woche mit {acc['favorite_medium']}.")

# %% [markdown]
# ## 6. Abschlussaufgabe – Einfaches Medien-Tracking
#
# Baue ein kleines Datenmodell für ein Medien-Tracking-System.
#
# Vorgabe:
#
# - Du verwaltest eine Liste `sessions`, in der jede Sitzung ein Dictionary ist mit:
#   - `"user"` – Name der Person
#   - `"medium"` – z. B. `"Film"`, `"Musik"`, `"Game"`, `"Podcast"`
#   - `"minutes"` – Dauer der Sitzung
#
# Beispiel:
#
# ```python
# sessions = [
#     {"user": "Alex", "medium": "Musik", "minutes": 30},
#     {"user": "Alex", "medium": "Game", "minutes": 45},
#     {"user": "Sam", "medium": "Film", "minutes": 120},
# ]
# ```
#
# Aufgaben:
#
# 1. Erzeuge eine Beispiel-Liste `sessions` mit mindestens 5 Einträgen.
# 2. Berechne die **Gesamtminuten pro Nutzer** (z. B. mit einem Dictionary `total_per_user`).
# 3. Berechne optional auch die Minuten pro Medium (z. B. `total_per_medium`).
# 4. Gib die Ergebnisse lesbar aus.
#
# Tipp: du kannst z. B. so vorgehen:
#
# ```python
# total_per_user = {}
# for session in sessions:
#     name = session["user"]
#     minutes = session["minutes"]
#     if name not in total_per_user:
#         total_per_user[name] = 0
#     total_per_user[name] += minutes
# ```

# %%
# TODO: Abschlussaufgabe – Medien-Tracking
sessions = [
    {"user": "Alex", "medium": "Musik", "minutes": 30},
    {"user": "Alex", "medium": "Game", "minutes": 45},
    {"user": "Sam", "medium": "Film", "minutes": 120},
    {"user": "Riley", "medium": "Podcast", "minutes": 25},
    {"user": "Sam", "medium": "Musik", "minutes": 40},
]

total_per_user = {}
for session in sessions:
    name = session["user"]
    minutes = session["minutes"]
    if name not in total_per_user:
        total_per_user[name] = 0
    total_per_user[name] += minutes

print("Gesamtminuten pro Nutzer:")
for name, minutes in total_per_user.items():
    print(f" - {name}: {minutes} Minuten")

# Optional: Minuten pro Medium
total_per_medium = {}
for session in sessions:
    medium = session["medium"]
    minutes = session["minutes"]
    if medium not in total_per_medium:
        total_per_medium[medium] = 0
    total_per_medium[medium] += minutes

print("\nGesamtminuten pro Medium:")
for medium, minutes in total_per_medium.items():
    print(f" - {medium}: {minutes} Minuten")

# %% [markdown]
# ---
# ## Zusammenfassung
#
# In diesem Modul hast du gelernt:
#
# - wie du Listen, Tupel, Dictionaries und Sets verwendest
# - wie du Einträge hinzufügst, änderst und löschst
# - wie du über Strukturen iterierst
# - wie du Datenstrukturen kombinierst, um kleine Modelle zu bauen
#
# Datenstrukturen sind die Grundlage für alles, was später mit Dateien, APIs, Datenbanken oder Machine Learning passiert.
#
# Als nächstes bietet sich an:
#
# - **Modul 05 – Arbeiten mit Dateien** (lesen/schreiben von Textdateien, einfache CSVs)
# - oder gezielte Übungen in deinem Level (A/B/C), die Datenstrukturen in einem kleinen Projekt-Kontext nutzen.
