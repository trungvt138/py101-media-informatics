# %% [markdown]
# # Modul 02 – Kontrollstrukturen (if, elif, else)
#
# In diesem Modul vertiefst du **Entscheidungen** in Python:
#
# 1. `if`-Anweisungen
# 2. `elif` und `else`
# 3. Mehrere Bedingungen mit `and`, `or`, `not`
# 4. Verschachtelte Entscheidungen (nested `if`)
# 5. Kleine praxisnahe Programmieraufgaben
#
# Ziel: Du kannst nach diesem Modul Programme schreiben, die sich je nach Eingabe unterschiedlich verhalten – z. B. Menüs, einfache Einstufungen oder kleine Tools für Medienanwendungen.

# %% [markdown]
# ## 1. Einfache `if`-Anweisung
#
# Eine `if`-Anweisung prüft eine Bedingung. Ist die Bedingung `True`, wird der eingerückte Block ausgeführt.
#
# ```python
# x = 10
#
# if x > 5:
#     print("x ist größer als 5")
# ```
#
# - Nach `if` steht eine Bedingung.
# - Am Zeilenende steht ein Doppelpunkt `:`.
# - Der zugehörige Block ist eingerückt (z. B. 4 Leerzeichen).

# %%
x = 10

if x > 5:
    print("x ist größer als 5")

print("Diese Zeile wird immer ausgeführt.")

# %% [markdown]
# ### Mini-Übung 1 – einfache Entscheidung
#
# Schreibe eine `if`-Anweisung, die prüft, ob `punkte` größer oder gleich `50` ist.
#
# - Wenn ja: gib aus `"Bestanden"`.
# - Ansonsten soll einfach nichts passieren (kein `else` nötig).

# %%
# TODO: Mini-Übung 1
punkte = 72  # ändere den Wert und teste

if punkte >= 50:
    print("Bestanden")

# %% [markdown]
# ## 2. `if`–`else`: Entweder-oder
#
# `else` wird ausgeführt, wenn die `if`-Bedingung **nicht** erfüllt ist.
#
# ```python
# alter = 16
#
# if alter >= 18:
#     print("Volljährig")
# else:
#     print("Noch nicht volljährig")
# ```

# %%
alter = 16

if alter >= 18:
    print("Volljährig")
else:
    print("Noch nicht volljährig")

# %% [markdown]
# ### Mini-Übung 2 – Medienfreigabe
#
# Schreibe ein kleines Programm, das:
#
# 1. das Alter einer Person per `input` abfragt,
# 2. prüft, ob das Alter mindestens `12` ist.
#
# - Wenn ja: gib aus `"Du darfst diesen Film schauen."`
# - Sonst: `"Du bist noch zu jung für diesen Film."`

# %%
# TODO: Mini-Übung 2 – Medienfreigabe
alter_text = input("Wie alt bist du? ")
alter = int(alter_text)

if alter >= 12:
    print("Du darfst diesen Film schauen.")
else:
    print("Du bist noch zu jung für diesen Film.")

# %% [markdown]
# ## 3. `if` – `elif` – `else`: Mehrere Fälle
#
# Mit `elif` ("else if") kannst du mehrere Bedingungen der Reihe nach prüfen.
#
# ```python
# punkte = 83
#
# if punkte >= 90:
#     note = 1
# elif punkte >= 80:
#     note = 2
# elif punkte >= 70:
#     note = 3
# else:
#     note = 4
# ```

# %%
punkte = 83

if punkte >= 90:
    note = 1
elif punkte >= 80:
    note = 2
elif punkte >= 70:
    note = 3
else:
    note = 4

print("Punkte:", punkte, "→ Note:", note)

# %% [markdown]
# ### Mini-Übung 3 – FSK-Einstufung
#
# Schreibe ein Programm, das basierend auf dem Alter eine grobe Kategorie ausgibt:
#
# - unter 6: `"FSK 0 / nur sehr kindgerechte Inhalte"`
# - 6–11: `"FSK 6 / kindgerechte Inhalte"`
# - 12–15: `"FSK 12 / für ältere Kinder und Jugendliche"`
# - ab 16: `"FSK 16 oder höher / jugendliche und erwachsene Inhalte"`
#
# Nutze dafür `if` / `elif` / `else` und eine Eingabe mit `input`.

# %%
# TODO: Mini-Übung 3 – FSK-Einstufung
alter_text = input("Wie alt bist du? ")
alter = int(alter_text)

if alter < 6:
    print("FSK 0 / nur sehr kindgerechte Inhalte")
elif alter < 12:
    print("FSK 6 / kindgerechte Inhalte")
elif alter < 16:
    print("FSK 12 / für ältere Kinder und Jugendliche")
else:
    print("FSK 16 oder höher / jugendliche und erwachsene Inhalte")

# %% [markdown]
# ## 4. Bedingungen kombinieren: `and`, `or`, `not`
#
# Du kannst mehrere Bedingungen kombinieren.
#
# Beispiele:
#
# ```python
# if alter >= 18 and hat_ausweis:
#     print("Du darfst rein.")
#
# if medium == "Film" or medium == "Serie":
#     print("Bewegtbild")
#
# if not ist_student:
#     print("Kein Studienstatus")
# ```

# %%
alter = 20
hat_ausweis = True
medium = "Film"
ist_student = False

if alter >= 18 and hat_ausweis:
    print("Du darfst in den 18+ Bereich.")

if medium == "Film" or medium == "Serie":
    print("Du schaust Bewegtbild.")

if not ist_student:
    print("Du scheinst kein*e Student*in zu sein.")

# %% [markdown]
# ### Mini-Übung 4 – Zugang prüfen
#
# Schreibe ein Programm, das prüft, ob eine Person Zugriff auf einen Bereich eines Medienportals hat.
#
# Variablen:
#
# - `alter` (int)
# - `ist_premium` (bool)
#
# Regeln:
#
# - Wenn `alter >= 18` **und** `ist_premium == True` → Ausgabe: `"Voller Zugriff."`
# - Wenn `alter >= 18`, aber **kein** Premium → Ausgabe: `"Standardzugriff (ohne Premium-Inhalte)."`
# - Wenn `alter < 18` → Ausgabe: `"Eingeschränkter Zugriff (Jugendschutz)."`

# %%
# TODO: Mini-Übung 4 – Zugang prüfen
alter = 17
ist_premium = False

if alter >= 18 and ist_premium:
    print("Voller Zugriff.")
elif alter >= 18 and not ist_premium:
    print("Standardzugriff (ohne Premium-Inhalte).")
else:
    print("Eingeschränkter Zugriff (Jugendschutz).")

# %% [markdown]
# ## 5. Verschachtelte `if`-Anweisungen
#
# Manchmal möchtest du **innen drin** noch eine weitere Entscheidung treffen. Das nennt man _verschachtelte_ `if`-Blöcke.
#
# ```python
# alter = 19
# ist_premium = True
#
# if alter >= 18:
#     if ist_premium:
#         print("Voller 18+ Premium-Zugriff")
#     else:
#         print("18+, aber ohne Premium")
# else:
#     print("Unter 18 – kein Zugriff auf 18+ Inhalte")
# ```

# %%
alter = 19
ist_premium = True

if alter >= 18:
    if ist_premium:
        print("Voller 18+ Premium-Zugriff")
    else:
        print("18+, aber ohne Premium")
else:
    print("Unter 18 – kein Zugriff auf 18+ Inhalte")

# %% [markdown]
# ### Mini-Übung 5 – Medien-Mix-Empfehlung
#
# Schreibe ein kleines Programm, das abhängig von:
#
# - `hat_viel_zeit` (bool)
# - `mag_games` (bool)
#
# eine einfache Empfehlung ausgibt:
#
# - wenn `hat_viel_zeit` und `mag_games`: `"Starte ein neues Game."`
# - wenn `hat_viel_zeit` und **nicht** `mag_games`: `"Schau eine Serie."`
# - wenn **nicht** `hat_viel_zeit` und `mag_games`: `"Spiel eine kurze Runde."`
# - sonst: `"Schau ein kurzes Video."`
#
# Du kannst dafür entweder:
# - mehrere `if` / `elif` / `else` kombinieren oder
# - verschachtelte `if`-Blöcke nutzen.

# %%
# TODO: Mini-Übung 5 – Medien-Mix-Empfehlung
hat_viel_zeit = True
mag_games = False

if hat_viel_zeit and mag_games:
    print("Starte ein neues Game.")
elif hat_viel_zeit and not mag_games:
    print("Schau eine Serie.")
elif not hat_viel_zeit and mag_games:
    print("Spiel eine kurze Runde.")
else:
    print("Schau ein kurzes Video.")

# %% [markdown]
# ## 6. While-Schleifen – Wiederholungen mit Bedingungen
#
# Bisher hast du mit `if`-Anweisungen **Entscheidungen** getroffen.
# Mit einer `while`-Schleife kannst du einen Codeblock so lange wiederholen,
# wie eine Bedingung **wahr** ist.
#
# Grundform:
#
# ```python
# count = 1
# while count <= 3:
#     print("Durchlauf", count)
#     count += 1
# ```
#
# Wichtig:
# - es gibt eine **Startvariable** (hier `count`)
# - die Bedingung (`count <= 3`) entscheidet, ob weiter gemacht wird
# - innerhalb der Schleife wird die Variable **verändert**, sonst läuft die Schleife unendlich

# %%
# Beispiel: einfache while-Schleife
count = 1
while count <= 3:
    print("Durchlauf", count)
    count += 1

# %% [markdown]
# ### Mini-Übung 6 – Zähle bis 5
#
# Schreibe eine `while`-Schleife, die die Zahlen **1 bis 5** ausgibt.
#
# Hinweise:
# - starte mit einer Variable `zahl = 1`
# - verwende als Bedingung z. B. `zahl <= 5`
# - erhöhe `zahl` in der Schleife mit `zahl += 1`

# %%
# TODO: Mini-Übung 6 – Zähle mit while von 1 bis 5
zahl = 1
while zahl <= 5:
    print(zahl)
    zahl += 1

# Du kannst hier auch mit anderen Grenzen experimentieren.

# %% [markdown]
# ## 7. Kleine Abschlussaufgabe – Einfacher Menü-Selector
#
# Schreibe ein kleines **Textmenü** für ein imaginäres Medienportal.
#
# Das Programm soll:
#
# 1. ein Menü anzeigen, z. B.:
#    ```
#    1) Musik abspielen
#    2) Film abspielen
#    3) Podcast abspielen
#    ```
# 2. die Eingabe einer Zahl (`input`) entgegennehmen
# 3. je nach Eingabe eine andere Ausgabe machen, z. B.:
#    - `"Starte Musik-Player..."`
#    - `"Starte Film-Player..."`
#    - `"Starte Podcast-Player..."`
# 4. Bei einer ungültigen Eingabe (z. B. `4`) soll ausgegeben werden:
#    - `"Ungültige Auswahl."`
#
# Nutze dafür `if` / `elif` / `else`.

# %%
# TODO: Abschlussaufgabe – Menü-Selector
print("Medienportal")
print("1) Musik abspielen")
print("2) Film abspielen")
print("3) Podcast abspielen")

wahl = input("Was möchtest du tun? (1/2/3) ")

if wahl == "1":
    print("Starte Musik-Player...")
elif wahl == "2":
    print("Starte Film-Player...")
elif wahl == "3":
    print("Starte Podcast-Player...")
else:
    print("Ungültige Auswahl.")

# %% [markdown]
# ---
# ## Zusammenfassung
#
# In diesem Modul hast du gelernt:
#
# - wie `if`, `elif` und `else` funktionieren
# - wie man mehrere Bedingungen mit `and`, `or`, `not` kombiniert
# - wie man verschachtelte Entscheidungen schreibt
# - wie man kleine interaktive Programme mit Eingaben und Verzweigungen baut
#
# - wie `while`-Schleifen funktionieren und einfache Wiederholungen umsetzen
# Damit bist du gut vorbereitet für:
#
# - **Modul 03 – Funktionen vertiefen** (eigene Funktionen, Parameter, Rückgabewerte)
# - komplexere Aufgaben und das Arbeiten in größeren Programmen.
#
# Wenn du dir unsicher bist, ob alles sitzt, spiel ruhig noch ein wenig mit den Beispielen – oder baue dein Menü-Programm weiter aus (z. B. mit Untermenüs oder Dummy-Texten wie "Hier könnte deine Playlist stehen").
