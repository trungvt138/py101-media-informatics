# %% [markdown]
# # Modul 01 – Python Basics
# In diesem Modul übst du die wichtigsten Grundlagen von Python:1. Ein- und Ausgabe (`print`, `input`)2. Datentypen (Zahlen, Strings, Booleans)3. Operatoren (Rechnen, Vergleiche, logische Operatoren)4. Typumwandlungen (`int`, `float`, `str`)5. Einfache kleine ProgrammeDieses Notebook ist so gedacht, dass du **aktiv mitprogrammierst**. Lies nicht nur – ändere Code, probiere aus, brich auch mal bewusst etwas kaputt, um aus Fehlern zu lernen 🙂

# %% [markdown]
# ## 1. Ausgabe mit `print`Mit `print(...)` kannst du Text und Werte auf der Konsole ausgeben.```pythonprint("Hallo Welt")```Du kannst mehrere Dinge auf einmal ausgeben, sie werden durch Leerzeichen getrennt:

# %%
print("Hallo", "Medieninformatik", 2025)

# %% [markdown]
# ### Mini-Übung 1 – Eigene AusgabeSchreibe eine `print`-Anweisung, die z. B. folgendes ausgibt:`"Ich studiere Medieninformatik und lerne Python."`

# %%
# TODO: Eigene Ausgabe mit printprint("Ich studiere Medieninformatik und lerne Python.")

# %% [markdown]
# ## 2. Eingabe mit `input`Mit `input(...)` kannst du Benutzer:innen etwas eingeben lassen. Das Ergebnis ist **immer ein String**.```pythonname = input("Wie heißt du? ")print("Hallo", name)```

# %%
# Du kannst diese Zelle ausführen und im Eingabefeld etwas eintippen.name = input("Wie heißt du? ")print("Hallo", name, "– willkommen im Python-Kurs!")

# %% [markdown]
# ### Mini-Übung 2 – Einfacher DialogSchreibe ein kleines Programm, das:1. nach deinem Namen fragt2. nach deinem Lieblingsmedium (z. B. Film, Musik, Game)3. eine kurze Antwort ausgibt, z. B.:`"Cool, Alex – Film ist ein spannendes Medium!"`

# %%
# TODO: Kleiner Dialog mit input und printname = input("Wie heißt du? ")medium = input("Was ist dein Lieblingsmedium (Film, Musik, Game, ...)? ")print("Cool,", name + " –", medium, "ist ein spannendes Medium!")

# %% [markdown]
# ## 3. Datentypen: Zahlen, Strings, BooleansDie wichtigsten einfachen Datentypen sind:- **Integer** (`int`) – ganze Zahlen, z. B. `3`, `42`, `-10`- **Float** (`float`) – Kommazahlen, z. B. `3.14`, `0.5`- **String** (`str`) – Zeichenketten, z. B. `"Hallo"`- **Boolean** (`bool`) – Wahrheitswerte: `True` oder `False`Du kannst dir den Typ mit `type(...)` anzeigen lassen:

# %%
x = 3y = 3.14text = "Hallo"flag = Trueprint(x, "hat Typ", type(x))print(y, "hat Typ", type(y))print(text, "hat Typ", type(text))print(flag, "hat Typ", type(flag))

# %% [markdown]
# ### Mini-Übung 3 – Typen ausprobierenLege selbst ein paar Variablen an, z. B.:- `jahr` (int)- `pi` (float)- `studiengang` (str)- `ist_medienmensch` (bool)Gib die Werte **und** ihre Typen aus.

# %%
# TODO: Eigene Variablen + Typen ausgebenjahr = 2025pi = 3.14159studiengang = "Medieninformatik"ist_medienmensch = Trueprint(jahr, type(jahr))print(pi, type(pi))print(studiengang, type(studiengang))print(ist_medienmensch, type(ist_medienmensch))

# %% [markdown]
# ## 4. Operatoren### 4.1 Rechenoperatoren- `+` Addition- `-` Subtraktion- `*` Multiplikation- `/` Division (Ergebnis ist immer ein Float)- `//` Ganzzahldivision- `%` Rest (Modulo)- `**` Potenz

# %%
a = 7b = 3print("a + b =", a + b)print("a - b =", a - b)print("a * b =", a * b)print("a / b =", a / b)print("a // b =", a // b)print("a % b =", a % b)print("a ** b =", a ** b)

# %% [markdown]
# ### Mini-Übung 4 – Sekunden in Minuten umrechnenSchreibe ein kleines Stück Code, das eine Variable `sekunden` nimmt und ausgibt, wie viele Minuten und Sekunden das sind.Beispiel: `sekunden = 197` → `3 Minuten und 17 Sekunden`.

# %%
# TODO: Sekunden in Minuten und Sekunden umrechnensekunden = 197minuten = sekunden // 60rest = sekunden % 60print(sekunden, "Sekunden sind", minuten, "Minuten und", rest, "Sekunden")

# %% [markdown]
# ### 4.2 Vergleichsoperatoren- `==` gleich- `!=` ungleich- `<`, `>`, `<=`, `>=`Sie liefern immer ein `True` oder `False` zurück.

# %%
x = 5y = 8print("x == y:", x == y)print("x != y:", x != y)print("x < y:", x < y)print("x >= 5:", x >= 5)

# %% [markdown]
# ### 4.3 Logische Operatoren- `and`- `or`- `not`Beispiele:

# %%
ist_student = Truehat_zeit = Falseprint("Student und Zeit:", ist_student and hat_zeit)print("Student oder Zeit:", ist_student or hat_zeit)print("Nicht Student:", not ist_student)

# %% [markdown]
# ### Mini-Übung 5 – Logik prüfenDefiniere zwei Booleans:- `mag_filme`- `mag_games`Schreibe Ausgaben, die prüfen:- ob du mindestens eines von beidem magst (`or`)- ob du beides magst (`and`).

# %%
# TODO: Eigene Booleans + logische Operatorenmag_filme = Truemag_games = Falseprint("Mag mindestens eins:", mag_filme or mag_games)print("Mag beides:", mag_filme and mag_games)

# %% [markdown]
# ## 5. TypumwandlungenDa `input(...)` immer einen String zurückgibt, musst du oft in `int` oder `float` umwandeln:```pythonzahl_text = input("Gib eine Zahl ein: ")zahl = int(zahl_text)print(zahl + 1)```Du kannst auch in String umwandeln:```pythonstr(42)  # ergibt "42"```

# %%
zahl_text = input("Gib eine ganze Zahl ein: ")zahl = int(zahl_text)print("Du hast", zahl, "eingegeben. In fünf Jahren bist du", zahl + 5, "Jahre alt (wenn das dein Alter war).")

# %% [markdown]
# ### Mini-Übung 6 – Kleiner RechnerSchreibe ein Programm, das:1. zwei Zahlen als Eingabe bekommt (mit `input`)2. beide in `float` umwandelt3. ihre Summe und ihr Produkt ausgibt.

# %%
# TODO: Kleiner Rechner mit input, float und Operatorenx_text = input("Erste Zahl: ")y_text = input("Zweite Zahl: ")x = float(x_text)y = float(y_text)print("Summe:", x + y)print("Produkt:", x * y)

# %% [markdown]
# ## 6. Kleine Abschluss-Aufgabe – Medien-spezifisches Mini-ProgrammSchreibe ein kleines Programm, das:1. nach deinem Namen fragt2. nach der Spieldauer deines Lieblingssongs in Sekunden fragt3. die Spieldauer in Minuten und Sekunden umrechnet4. eine Ausgabe macht wie z. B.:`"Alex, dein Lieblingssong dauert 3 Minuten und 45 Sekunden."`Nutze dafür alles, was du bisher in diesem Notebook gesehen hast.

# %%
# TODO: Abschluss-Aufgabename = input("Wie heißt du? ")dauer_text = input("Wie viele Sekunden dauert dein Lieblingssong? ")dauer = int(dauer_text)minuten = dauer // 60sekunden = dauer % 60print(f"{name}, dein Lieblingssong dauert {minuten} Minuten und {sekunden} Sekunden.")

# %% [markdown]
# ---## ZusammenfassungIn diesem Notebook hast du gesehen:- wie man in Python mit `print` und `input` arbeitet- wie man Variablen und einfache Datentypen verwendet- wie Operatoren für Rechnen, Vergleiche und Logik funktionieren- wie man Typen mit `int`, `float` und `str` umwandeltWenn dir diese Basics vertraut sind, bist du bereit für:- **Modul 02 – Kontrollstrukturen** (if/elif/else, komplexere Bedingungen)- weitere Übungen in deinem Level (A/B/C).Speichere das Notebook gerne ab – es ist eine gute Referenz für alle weiteren Aufgaben.
