# %% [markdown]
# # Level A – Übungsset 01
# Einsteigerübungen für Studierende mit wenig Python-Erfahrung.
#
# Dieses Übungsset knüpft an die Module **01–04** an.
# Es enthält 10 Aufgaben, jeweils mit Startercode. Lösungshinweise sind auskommentiert.

# %% [markdown]
# ## A1 – Temperatur umrechnen (Celsius → Fahrenheit)
# Formel:
# `fahrenheit = celsius * 9/5 + 32`

# %%
celsius = 20  # ändere die Zahl für Tests
fahrenheit = celsius * 9/5 + 32
print(f"{celsius}°C entsprechen {fahrenheit}°F")

# Lösungshinweis:
# Fahrenheit = Celsius * 9/5 + 32

# %% [markdown]
# ## A2 – String zusammensetzen
# Baue einen Satz wie:
# `"Hallo Alex Müller, willkommen im Studiengang Medieninformatik!"`

# %%
firstname = "Alex"
lastname = "Müller"
study_program = "Medieninformatik"

sentence = f"Hallo {firstname} {lastname}, willkommen im Studiengang {study_program}!"
print(sentence)

# Lösungshinweis: Nutze f-Strings.

# %% [markdown]
# ## A3 – Kleine Playlist
# Erstelle eine Liste mit drei Songs und gib jeden in einer Schleife aus.

# %%
playlist = ["Song A", "Song B", "Song C"]

for song in playlist:
    print("-", song)

# Lösungshinweis: Liste + for-Schleife.

# %% [markdown]
# ## A4 – Durchschnitt berechnen
# Gegeben:
# `minutes = [10, 20, 30, 25]`

# %%
minutes = [10, 20, 30, 25]

total = sum(minutes)
avg = total / len(minutes)

print("Gesamt:", total)
print("Durchschnitt:", avg)

# Lösungshinweis: sum() und len() nutzen.

# %% [markdown]
# ## A5 – Längsten Song ohne `max()` finden
# Gegeben:
# `songs = [180, 220, 210, 95, 300]`

# %%
songs = [180, 220, 210, 95, 300]

longest = songs[0]
for s in songs:
    if s > longest:
        longest = s

print("Längster Song:", longest)

# Lösungshinweis: Mit Vergleich in Schleife.

# %% [markdown]
# ## A6 – Medienprofil
# Erstelle ein Dictionary und gib alle Schlüssel/Werte aus.

# %%
profile = {
    "name": "Alex",
    "likes_music": True,
    "minutes_music": 45,
}

for key, value in profile.items():
    print(f"{key}: {value}")

# Lösungshinweis: dict.items() verwenden.

# %% [markdown]
# ## A7 – Minuten pro Medium addieren
# Gegeben ist eine Liste von Dictionaries.

# %%
sessions = [
    {"medium": "Musik", "minutes": 30},
    {"medium": "Film", "minutes": 90},
    {"medium": "Musik", "minutes": 20},
]

totals = {}
for s in sessions:
    m = s["medium"]
    minutes = s["minutes"]
    totals[m] = totals.get(m, 0) + minutes

print(totals)

# Lösungshinweis: dict.get() nutzen.

# %% [markdown]
# ## A8 – Begrüßungsfunktion

# %%
def greet(name):
    print(f"Hallo {name}, schön dass du da bist!")

greet("Lea")

# Lösungshinweis: Funktion mit einem Parameter.

# %% [markdown]
# ## A9 – Sekunden in Minuten/Sekunden umwandeln

# %%
def to_min_sec(seconds):
    minutes = seconds // 60
    secs = seconds % 60
    return minutes, secs

print(to_min_sec(197))

# Lösungshinweis: Ganzzahldivision und Rest.

# %% [markdown]
# ## A10 – Session beschreiben
# Erzeuge eine Funktion, die ein Session-Dictionary schön formatiert.

# %%
def describe_session(session):
    return f"{session['user']} nutzte {session['medium']} für {session['minutes']} Minuten."

session = {"user": "Alex", "medium": "Musik", "minutes": 30}
print(describe_session(session))

# Lösungshinweis: Zugriff auf dict-Werte + f-String.

# %% [markdown]
# ## A11 – While-Schleife: Zähle bis 10
#
# Schreibe eine `while`-Schleife, die die Zahlen **1 bis 10** ausgibt.
#
# Hinweis: Du brauchst eine Variable, die du in jedem Schleifendurchlauf erhöhst.

# %%
# TODO: Zähle mit while von 1 bis 10
num = 1
while num <= 10:
    print(num)
    num += 1

# Lösungshinweis:
# Starte bei 1 und erhöhe in jedem Schritt um 1.

# %% [markdown]
# ## A12 – Mini-Menü mit while
#
# Erstelle ein kleines Menü, das so lange läuft, bis der/die Nutzer:in `"q"` eingibt.
#
# Menü:
# - `1` → „Hallo!“ ausgeben
# - `2` → „Python macht Spaß!“ ausgeben
# - `q` → Programm beenden
#
# Nutze dazu eine `while`-Schleife und `input()`.

# %%
# TODO: Mini-Menü mit while-Schleife
choice = ""
while choice != "q":
    print("\n--- Menü ---")
    print("1) Hallo sagen")
    print("2) Python macht Spaß")
    print("q) Beenden")
    choice = input("Auswahl: ")

    if choice == "1":
        print("Hallo!")
    elif choice == "2":
        print("Python macht Spaß!")
    elif choice == "q":
        print("Programm beendet.")
    else:
        print("Ungültige Eingabe.")
